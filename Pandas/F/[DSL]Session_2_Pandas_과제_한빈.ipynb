# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### 코랩 사용시

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.getcwd()
# Out:
# '/content'

# %% [markdown]
# 코랩 사용시 본인 구글 드라이브 경로는
# /content/drive/MyDrive/...
# 입니다.

# %%
path = './drive/MyDrive/...'    # 과제 데이터셋이 저장된 경로를 더 작성해주세요
os.chdir(path)

# %%
os.getcwd()

# %% [markdown]
# #### 과제 본문

# %% [markdown]
# 실제 데이터를 이용해 전처리를 진행합니다.
# 에어비앤비 dataset 일부를 사용합니다.

# %% [markdown]
# (1) 'airbnb_과제용.csv' 파일을 pd.read_csv() 메소드를 이용하여 불러옵니다.
# 이때 할당할 변수명은 df로 지정하고, 매개변수를 사용하여 'id' 열을 DataFrame의 인덱스로 지정합니다.

# %% [markdown]
# 예시)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (2) 다음 열들이 필요없다고 가정하고, 그 열들을 제거해주려고 합니다.
# 적절한 메소드를 사용해서 다음 열들을 제거해주세요.
# - 'room_type', 'description', 'first_review', 'last_review'

# %% [markdown]
# 예시)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (3) 칼럼들의 순서를 보기좋게 바꾸고자 합니다. 순서는 다음과 같습니다.
# - 'log_price', 'review_scores_rating', 'number_of_reviews', 'property_type',
# 'city', 'latitude', 'longitude', 'amenities'
#
# 그 후 칼럼의 이름을 다음과 같이 바꾸고자 합니다.
# - 'log_price', 'score', 'num_review', 'property_type',
# 'city', 'lat', 'lon', 'amenities'
#
# 적절한 메소드를 사용하여 위의 두 작업을 진행해주세요.

# %% [markdown]
# 예시)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (4) 결측치가 어느 열에 몇 개나 있는지 확인하고자 합니다.
# 예시 사진과 같이 요약정보를 출력해보세요.

# %% [markdown]
# 예시)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (5) 'score' 칼럼에 결측치가 존재하는 것 같습니다.
# 결측치가 포함된 행을 모두 삭제해주세요.

# %% [markdown]
# 예시)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (6) log_price의 값이 4 이상인 행만 인덱싱하여 df 변수에 할당하세요.
# 그리고 num_review 열의 값이 5 이상인 행만 인덱싱하여 df 변수에 할당하세요.

# %% [markdown]
# 예시)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (7) DataFrame을 인덱스인 'id'를 기준으로 내림차순 정렬해주세요.

# %% [markdown]
# 예시)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (8) lat과 lon 칼럼의 값을 소수점 둘째자리까지 반올림해주세요.
# 단, apply 메소드와 lambda 익명함수, numpy의 around 메소드를 모두 활용해주세요.

# %% [markdown]
# 예시)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (9) 피벗 테이블을 만들고자 합니다.
# pivot이라는 변수를 새로 만들어 이 변수에 피벗테이블을 할당합니다.
# 행 방향으로 city, property_type의 종류를 계층적으로 배치합니다.
# 요약정보를 뽑아낼 값은 log_price와 score이고,
# 요약하는 방법으로는 두 값 모두 max, mean, min입니다.

# %% [markdown]
# 예시)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (10) 마지막으로 전처리한 DataFrame을 csv파일로 저장하고자 합니다.
# index 역시 포함하여 저장되도록 하고, 파일명은 '이름_기초세션제출.csv' 입니다.

# %% [markdown]
# (11) 수고하셨습니다! 이제 저장한 '이름_기초세션제출.csv' 파일과 현재 노트북(ipynb) 파일을 제출해주시면 됩니다.

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# **★ 추가 과제 ★** (도전해보고 싶은 분들만!)
# amenities 칼럼을 다듬으려고 합니다. 해당 칼럼에는 다양한 편의시설이 나열되어 있는데,
# 양 끝은 '{' 와 '}' 로 감싸져 있고, 각 항목은 ','로 구분되어있습니다.
# 또한 "(큰따옴표)가 있는 것도 있고, 없는 것도 있습니다.

# %% [markdown]
# 우리는 amenities 칼럼의 값을 편의시설의 개수로 변경하고자 합니다.
# 각 과정에서 replace나 apply 메소드, 또한 그 외의 방법을 이용하여 전처리를 해보세요.

# %% [markdown]
# 예시)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 수고하셨습니다.
