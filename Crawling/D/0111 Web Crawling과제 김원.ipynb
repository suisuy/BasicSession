# %%
#정보 요청 라이브러리
# !pip install requests

#크롤링의 대부 라이브러리
# !pip install beautifulsoup4

#구문 분석 라이브러리
# !pip install lxml

#동적 컨트롤도 가능한 크롤링 라이브러리
# !pip install selenium
# Out:
# ...
#   Using cached urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.8
#     Uninstalling urllib3-1.26.8:
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] 액세스가 거부되었습니다: 'c:\\programdata\\anaconda3\\lib\\site-packages\\urllib3-1.26.8.dist-info\\INSTALLER'
# Consider using the `--user` option or check the permissions.
# ...

# %%
#정보요청 라이브러리 import
import requests
#정보요청 라이브러리2 불러오기
import urllib

#크롤링 라이브러리 import
from bs4 import BeautifulSoup
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
#User-Agent 지정
headers = {'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36'}

# %%
#크롤링 할 대상 url 지정
url = 'https://www.saramin.co.kr/zf_user/jobs/list/domestic'

#크롤링 대상 url과 headers를 기반으로 정보 요청
res = requests.get(url, headers = headers)

#정상적으로 정보를 받은 경우 지속, 그렇지 않은 경우 중지
res.raise_for_status()

#html문서를 beautifulsoup의 lxml 형태로 변환
soup = BeautifulSoup(res.text, 'lxml')

# %%
#html문서에서 'str_tit'라는 이름의 class를 지닌 'a'태그의 element들 모두 선택
cptitle = soup.findAll('a', attrs={'class' : 'str_tit'})

# %%
cptitle
# Out:
# [<a class="str_tit" href="/zf_user/jobs/relay/view?view_type=list&amp;rec_idx=42010646" onclick="s_trackApply(this, 'area_recruit', 'general');" target="_blank" title="(주)분코"><span>(주)분코</span></a>,
#  <a class="str_tit" href="/zf_user/jobs/relay/view?view_type=list&amp;rec_idx=42010646" id="rec_link_42010646" onclick="s_trackApply(this, 'area_recruit', 'general');" onmousedown="Saramin.clickAds(42010646, 'ads_category=section_favor_003')" target="_blank" title="(주)분코 생활용품 &amp;amp; 뷰티 브랜드 영업/해외영업 [신입/경력]"><span>(주)분코 생활용품 &amp; 뷰티 브랜드 영업/해외영업 [신입/경력]</span></a>,
#  <a class="str_tit" href="/zf_user/jobs/relay/view?view_type=list&amp;rec_idx=41830647" onclick="s_trackApply(this, 'area_recruit', 'general');" target="_blank" title="(주)명지메디칼"><span>(주)명지메디칼</span></a>,
# ...

# %%
#글자들을 분류 
lst_title= []
for a in cptitle:
    lst_title.append(a['title'])
len(lst_title)
lst_title
# Out:
# ['(주)분코',
#  '(주)분코 생활용품 &amp; 뷰티 브랜드 영업/해외영업 [신입/경력]',
#  '(주)명지메디칼',
#  '의료기기 영업사원(종합병원) 모집 신입, 경력무관',
#  '(주)동림철강',
#  '영업직 채용 공고',
#  '(주)이레테크',
#  '이레테크 성암공장 매입마감 및 총무업무 직원 모집',
#  '미츠바상사',
#  '[물류팀] 패킹/상하차/물류관리 정규직 채용 - 경력무관',
#  '에이치와이씨(주)',
#  '중남미지역 해외영업 신입&amp;경력 채용(스페인어)',
#  '누베스(주)',
#  '누베스 각 부문(재단/단순조립) 담당직원 모집',
#  '(주)에이치와이코퍼레이션',
#  '2021년 각부문별 정규직 신입사원 채용',
#  '(주)피비이뮨테라퓨틱스',
#  '(주)피비이뮨테라퓨틱스 연구원 채용 공고',
#  '진구링구아어학원',
#  '영어학원 총무과 데스크 선생님 구합니다.',
#  '(주)빈티지코리아',
#  '마케팅/물류 직원 신규채용',
#  '청림출판(주)',
#  '청림출판㈜에서 해외도서 기획 업무 인재를 모십니다',
#  '(주)에스엔바이오로직스',
#  '[신입] 의료기기 제조업 정규직 채용',
#  '(주)에스클로버',
#  '[ 정규직 ] 상품지원부 / 영업부 신입 및 경력 채용',
#  '(주)구름연구소',
#  '구름연구소 컨설턴트 채용(ICT/정책/경영/AI)(신입,경력)',
#  '맨파워코리아',
#  '글로벌 스포츠브랜드 제조회사 IT Specialist 채용 (경력자)',
#  '주식회사 천명',
#  '단순생산직(정규직) /조립/생산AS 직원 모집',
#  '(주)에스디시',
#  '총무, 사무보조(관리팀 업무) 모집-경력자',
#  '(주)릭스솔루션',
#  '사업지원 담당자 정규직 모집 (신입)',
#  '(주)원에이치알코퍼레이션',
#  '[원에이치알컴퍼니] 인사노무관리 신입 및 경력직 공채 모집',
#  '가연금속공예',
# ...

# %%
cp_name=lst_title[0:80:2]
cp_title=lst_title[1:80:2]
len(cp_name)
# Out:
# 40

# %%
cp_name
# Out:
# ['(주)분코',
#  '(주)명지메디칼',
#  '(주)동림철강',
#  '(주)이레테크',
#  '미츠바상사',
#  '에이치와이씨(주)',
#  '누베스(주)',
#  '(주)에이치와이코퍼레이션',
#  '(주)피비이뮨테라퓨틱스',
#  '진구링구아어학원',
#  '(주)빈티지코리아',
#  '청림출판(주)',
#  '(주)에스엔바이오로직스',
#  '(주)에스클로버',
#  '(주)구름연구소',
#  '맨파워코리아',
#  '주식회사 천명',
#  '(주)에스디시',
#  '(주)릭스솔루션',
#  '(주)원에이치알코퍼레이션',
#  '가연금속공예',
#  '(주)코빌시스',
#  '주식회사 광문당1937',
#  '(주)케이디에스 디앤티',
#  '(주)어펙션',
#  '(주)퀀티파이드이에스지',
#  '맨파워코리아',
#  '(주)케이엑스비션스',
#  '남부여객자동차(주)',
#  '(주)베스트건축비아이엠엔지니어링',
#  '(주)신도리코 중앙지점',
#  '(주)맨파워그룹코리아',
#  '주식회사 위드웍스',
#  'CJ Telenix',
#  '현대그린테크(주)',
#  '(주)엔피케이',
#  '(주)세움플래닛',
#  '(유)랍코리아',
#  '(주)에스에스지산업',
#  '(주)덤코리아']

# %%
import pandas as pd

# %%
final_df = pd.DataFrame({ '회사이름':cp_name, '회사제목':cp_title })
final_df
# Out:
#                  회사이름                                     회사제목
# 0               (주)분코  (주)분코 생활용품 &amp; 뷰티 브랜드 영업/해외영업 [신입/경력]
# 1            (주)명지메디칼              의료기기 영업사원(종합병원) 모집 신입, 경력무관
# 2             (주)동림철강                                영업직 채용 공고
# 3             (주)이레테크              이레테크 성암공장 매입마감 및 총무업무 직원 모집
# 4               미츠바상사          [물류팀] 패킹/상하차/물류관리 정규직 채용 - 경력무관
# 5           에이치와이씨(주)            중남미지역 해외영업 신입&amp;경력 채용(스페인어)
# 6              누베스(주)                누베스 각 부문(재단/단순조립) 담당직원 모집
# 7       (주)에이치와이코퍼레이션                   2021년 각부문별 정규직 신입사원 채용
# 8        (주)피비이뮨테라퓨틱스                   (주)피비이뮨테라퓨틱스 연구원 채용 공고
# 9            진구링구아어학원                   영어학원 총무과 데스크 선생님 구합니다.
# 10          (주)빈티지코리아                           마케팅/물류 직원 신규채용
# 11            청림출판(주)              청림출판㈜에서 해외도서 기획 업무 인재를 모십니다
# 12       (주)에스엔바이오로직스                     [신입] 의료기기 제조업 정규직 채용
# 13           (주)에스클로버           [ 정규직 ] 상품지원부 / 영업부 신입 및 경력 채용
# ...
